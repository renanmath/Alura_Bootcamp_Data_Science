# %% [markdown]
# <a href="https://colab.research.google.com/github/renanmath/Alura_Bootcamp_Data_Science/blob/main/Alura_Bootcamp_Modulo02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Previously on Módulo 01

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore') #ignora os avisos
pd.options.display.float_format = "{:,.2f}".format #ajusta o formato numérico exibido

# %% [markdown]
# ## Aquisição e tratamento dos dados

# %%
df = pd.read_csv("/content/A184117189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")

# %%
colunas_usaveis = df.mean().index.tolist()

# %%
lista_regioes = ['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste']
lista_regioes
# Out:
# ['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste']

# %%
coluna_regioes = []
for i in range(0,df.shape[0]):
  dig = int(df['Unidade da Federação'][i][0])
  coluna_regioes.append(lista_regioes[dig-1])
df['Região'] = coluna_regioes

df['Unidade da Federação'] = df['Unidade da Federação'].str.slice(3,)
df = df.set_index('Unidade da Federação')
df
# Out:
#                       1992/Mar  1992/Abr  ...         Total        Região
# Unidade da Federação                      ...
# Rondônia                     -         -  ...  9.964113e+08         Norte
# Acre                         -         -  ...  4.500485e+08         Norte
# Amazonas                     -         -  ...  1.917248e+09         Norte
# Roraima                      -         -  ...  3.288770e+08         Norte
# Pará                         -         -  ...  4.705309e+09         Norte
# Amapá                        -         -  ...  3.098601e+08         Norte
# Tocantins                    -         -  ...  1.020028e+09         Norte
# Maranhão                     -         -  ...  3.871069e+09      Nordeste
# Piauí                        -         -  ...  2.280889e+09      Nordeste
# Ceará                        -         -  ...  6.591837e+09      Nordeste
# Rio Grande do Norte          -         -  ...  2.660122e+09      Nordeste
# Paraíba                      -         -  ...  2.614919e+09      Nordeste
# Pernambuco                   -         -  ...  8.581190e+09      Nordeste
# Alagoas                      -         -  ...  2.236415e+09      Nordeste
# Sergipe                      -         -  ...  1.215853e+09      Nordeste
# Bahia                        -         -  ...  9.791542e+09      Nordeste
# Minas Gerais                 -         -  ...  2.041874e+10       Sudeste
# Espírito Santo               -         -  ...  3.405851e+09       Sudeste
# Rio de Janeiro               -         -  ...  1.033739e+10       Sudeste
# São Paulo             40243.16  11449.99  ...  4.139641e+10       Sudeste
# Paraná                       -         -  ...  1.468151e+10           Sul
# Santa Catarina               -         -  ...  7.835011e+09           Sul
# Rio Grande do Sul            -         -  ...  1.276439e+10           Sul
# Mato Grosso do Sul           -         -  ...  2.324525e+09  Centro-Oeste
# Mato Grosso                  -         -  ...  2.180120e+09  Centro-Oeste
# Goiás                        -         -  ...  4.973572e+09  Centro-Oeste
# Distrito Federal             -         -  ...  2.592423e+09  Centro-Oeste
#
# [27 rows x 287 columns]

# %%
dados_usaveis = df[['Região'] + colunas_usaveis]

# %%
dados_usaveis
# Out:
#                             Região    2007/Ago  ...      2021/Mar         Total
# Unidade da Federação                            ...
# Rondônia                     Norte     4209.37  ...  4.732441e+06  9.964113e+08
# Acre                         Norte    10470.07  ...  1.137342e+06  4.500485e+08
# Amazonas                     Norte    35752.72  ...  6.799061e+06  1.917248e+09
# Roraima                      Norte     4785.91  ...  2.381844e+06  3.288770e+08
# Pará                         Norte   181159.29  ...  1.306956e+07  4.705309e+09
# Amapá                        Norte    33672.74  ...  9.891554e+05  3.098601e+08
# Tocantins                    Norte     4113.76  ...  9.287568e+05  1.020028e+09
# Maranhão                  Nordeste   385330.18  ...  1.729451e+07  3.871069e+09
# Piauí                     Nordeste   220788.25  ...  9.542152e+06  2.280889e+09
# Ceará                     Nordeste   357904.65  ...  1.717315e+07  6.591837e+09
# Rio Grande do Norte       Nordeste   134605.36  ...  8.733455e+06  2.660122e+09
# Paraíba                   Nordeste    97352.78  ...  1.251789e+07  2.614919e+09
# Pernambuco                Nordeste   400640.85  ...  3.947274e+07  8.581190e+09
# Alagoas                   Nordeste   104243.75  ...  8.180887e+06  2.236415e+09
# Sergipe                   Nordeste    27453.63  ...  3.081081e+06  1.215853e+09
# Bahia                     Nordeste   135146.36  ...  3.131460e+07  9.791542e+09
# Minas Gerais               Sudeste   971394.37  ...  7.978084e+07  2.041874e+10
# Espírito Santo             Sudeste    57408.11  ...  1.560637e+07  3.405851e+09
# Rio de Janeiro             Sudeste   469469.34  ...  4.914988e+07  1.033739e+10
# São Paulo                  Sudeste  1665349.90  ...  1.774083e+08  4.139641e+10
# Paraná                         Sul   554800.22  ...  4.348073e+07  1.468151e+10
# Santa Catarina                 Sul   693955.05  ...  1.937582e+07  7.835011e+09
# Rio Grande do Sul              Sul  1049252.33  ...  3.779883e+07  1.276439e+10
# Mato Grosso do Sul    Centro-Oeste   199556.12  ...  4.035990e+06  2.324525e+09
# Mato Grosso           Centro-Oeste    63562.50  ...  8.835890e+06  2.180120e+09
# Goiás                 Centro-Oeste   179395.82  ...  2.486700e+07  4.973572e+09
# Distrito Federal      Centro-Oeste   191951.47  ...  1.473194e+07  2.592423e+09
#
# [27 rows x 166 columns]

# %% [markdown]
# Inserindo a coluna região

# %% [markdown]
# # Aula 01: Fontes externas, limpeza e manipulação

# %% [markdown]
# Como extrair dados popopulacionais contidos na primeira tabela desta [página da Wikipedia]('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o)? Uma maneira de fazer é copiar e colar diretamente no código (utilizando três aspas duplas):

# %%
dados_populacao = """
Posição	Unidade federativa	População	% da pop. total	País comparável
1	 São Paulo	46 289 333	21,9%	 Espanha (46 439 864)
2	 MG Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# %% [markdown]
# E utilizamos o código:

# %%
from io import StringIO
pop_io = StringIO(dados_populacao)

pop_wiki = pd.read_csv(pop_io, sep = '\t')
pop_wiki

# %% [markdown]
# Vamos limpar um pouco essa tabela:

# %%
pop_wiki.columns = ['posicao', 'uf', 'populacao', '% pop total', 'pais comparavel']
pop_wiki.drop(['posicao', 'pais comparavel'], axis = 1, inplace=
              True)
pop_wiki = pop_wiki.set_index('uf')
pop_wiki.replace(' ','', inplace=True, regex=True)
pop_wiki.replace('%','', inplace=True, regex=True)
pop_wiki.replace(',','.', inplace=True, regex=True)

pop_wiki['populacao'] = pop_wiki['populacao'].astype(int)
pop_wiki['% pop total'] = pop_wiki['% pop total'].astype(float)

pop_wiki
# Out:
#                       populacao  % pop total
# uf
#  São Paulo             46289333         21.9
#  MG Minas Gerais       21292666         10.1
#  Rio de Janeiro        17366189          8.2
# Bahia Bahia            14930634          7.1
#  Paraná                11516840          5.4
#  Rio Grande do Sul     11422973          5.4
#  Pernambuco             9616621          4.5
#  Ceará                  9187103          4.3
# Pará Pará               8690745          4.1
#  Santa Catarina         7252502          3.4
#  Maranhão               7114598          3.4
#  Goiás                  7113540          3.4
#  Amazonas               4207714          2.0
#  Espírito Santo         4064052          1.9
#  Paraíba                4039277          1.9
#  Rio Grande do Norte    3534165          1.7
#  Mato Grosso            3526220          1.7
#  Alagoas                3351543          1.6
#  Piauí                  3281480          1.6
#  Distrito Federal       3055149          1.4
#  Mato Grosso do Sul     2809394          1.3
#  Sergipe                2318822          1.1
#  Rondônia               1796460          0.8
#  Tocantins              1590248          0.7
#  Acre                    894470          0.4
#  Amapá                   861773          0.4
#  Roraima                 631181          0.3

# %% [markdown]
# Uma segunda maneira de obter essa mesma tabela é utilizar o read_html em vez do read_csv do pandas:

# %%
pop_wiki2 = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o')

# %%
pop_wiki2
# Out:
# [    Posição  ...        País comparável (habitantes)
#  0         1  ...                Espanha (46 439 864)
#  1         2  ...              Sri Lanka (20 675 000)
#  2         3  ...          Países Baixos (16 922 900)
#  3         4  ...                  Chade (14 037 000)
#  4         5  ...                Bolívia (11 410 651)
#  5         6  ...                Bélgica (11 250 659)
#  6         7  ...            Bielorrússia (9 485 300)
#  7         8  ...  Emirados Árabes Unidos (9 157 000)
#  8         9  ...                 Áustria (8 602 112)
#  9        10  ...                  Sérvia (7 114 393)
#  10       11  ...                Paraguai (7 003 406)
#  11       12  ...                Paraguai (7 003 406)
#  12       13  ...                  Líbano (4 168 000)
#  13       14  ...                  Líbano (4 168 000)
#  14       15  ...                  Líbano (4 168 000)
#  15       16  ...                 Uruguai (3 415 866)
#  16       17  ...                 Uruguai (3 415 866)
#  17       18  ...                 Uruguai (3 415 866)
#  18       19  ...                  Kuwait (3 268 431)
#  19       20  ...                Lituânia (2 900 787)
#  20       21  ...                 Jamaica (2 717 991)
#  21       22  ...                 Namíbia (2 280 700)
#  22       23  ...                   Gabão (1 725 000)
#  23       24  ...                 Bahrein (1 359 800)
#  24       25  ...                      Fiji (859 178)
#  25       26  ...                      Fiji (859 178)
#  26       27  ...                Luxemburgo (562 958)
#
#  [27 rows x 5 columns],
#     Posição  ...                 País comparável (habitantes)
#  0        1  ...  República Democrática do Congo (86 790 567)
#  1        2  ...                   África do Sul (58 775 022)
#  2        3  ...                           Nepal (29 609 623)
#  3        4  ...                     Cazaquistão (18 574 680)
#  4        5  ...                         Senegal (16 209 125)
#
#  [5 rows x 5 columns],
#                     Região                                                UFs
#  0         Norte prefixo 1          RO AC AM RR PA AP TO 11 12 13 14 15 16 17
#  1      Nordeste prefixo 2  MA PI CE RN PB PE AL SE BA 21 22 23 24 25 26 2...
#  2       Sudeste prefixo 3                            MG ES RJ SP 31 32 33 35
#  3           Sul prefixo 4                                  PR SC RS 41 42 43
#  4  Centro-Oeste prefixo 5                            MS MT GO DF 50 51 52 53,
#     vdeClassificações das unidades federativas do Brasil vdeClassificações das unidades federativas do Brasil.1
#  0                         Características geográficas    Área Densidade demográfica Número de município...
#  1                            Indicadores demográficos    População Densidade demográfica Natalidade Fec...
#  2                                      Gestão pública    Sedes governamentais Transparência Arrecadação...
#  3                    Indicadores econômicos e sociais    PIB Série histórica 1939 1950 1960 1970 1980 1...
#  4                                                 PIB    Série histórica 1939 1950 1960 1970 1980 1990 ...
#  5                                            Trabalho    Empregados com carteira assinada Desemprego Ap...
#  6                            Desigualdade e bem-estar    Segurança alimentar Renda per capita IDH segun...
#  7                                            Educação    Alfabetização Crianças e adolescentes fora da ...
#  8                                               Saúde    Mortalidade infantil Óbitos infantis Taxa de h...
#  9                                              Outros    Religião Circunscrições eclesiásticas Competit...
#  10                                           Símbolos                              Bandeiras Brasões Hinos    ,
#                            0                                                  1
#  0                       PIB  Série histórica 1939 1950 1960 1970 1980 1990 ...
#  1                  Trabalho  Empregados com carteira assinada Desemprego Ap...
#  2  Desigualdade e bem-estar  Segurança alimentar Renda per capita IDH segun...
#  3                  Educação  Alfabetização Crianças e adolescentes fora da ...
#  4                     Saúde  Mortalidade infantil Óbitos infantis Taxa de h...
#  5                    Outros  Religião Circunscrições eclesiásticas Competit...]

# %% [markdown]
# Observe que esse comando nos dá não uma tabela, mas a lista de todas as tabelas contidas no endereço html passado. Já que é uma lista, podemos selecionar o elemento que desejarmos, bastando passar o índice (posição) dele na lista:

# %%
pop_wiki2 = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o')[0]

# %%
pop_wiki2
# Out:
#     Posição  ...        País comparável (habitantes)
# 0         1  ...                Espanha (46 439 864)
# 1         2  ...              Sri Lanka (20 675 000)
# 2         3  ...          Países Baixos (16 922 900)
# 3         4  ...                  Chade (14 037 000)
# 4         5  ...                Bolívia (11 410 651)
# 5         6  ...                Bélgica (11 250 659)
# 6         7  ...            Bielorrússia (9 485 300)
# 7         8  ...  Emirados Árabes Unidos (9 157 000)
# 8         9  ...                 Áustria (8 602 112)
# 9        10  ...                  Sérvia (7 114 393)
# 10       11  ...                Paraguai (7 003 406)
# 11       12  ...                Paraguai (7 003 406)
# 12       13  ...                  Líbano (4 168 000)
# 13       14  ...                  Líbano (4 168 000)
# 14       15  ...                  Líbano (4 168 000)
# 15       16  ...                 Uruguai (3 415 866)
# 16       17  ...                 Uruguai (3 415 866)
# 17       18  ...                 Uruguai (3 415 866)
# 18       19  ...                  Kuwait (3 268 431)
# 19       20  ...                Lituânia (2 900 787)
# 20       21  ...                 Jamaica (2 717 991)
# 21       22  ...                 Namíbia (2 280 700)
# 22       23  ...                   Gabão (1 725 000)
# 23       24  ...                 Bahrein (1 359 800)
# 24       25  ...                      Fiji (859 178)
# 25       26  ...                      Fiji (859 178)
# 26       27  ...                Luxemburgo (562 958)
#
# [27 rows x 5 columns]

# %% [markdown]
# Não foi necessário nesse caso, mas se quiséssemos, poderíamos ainda ter passado o comando match = (algum elemento que ajude a identificar a tabela). Assim o read_html iria retormar apenas as tabelas com aquele elemento. Vejamos:

# %%
pop_wiki2 = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o', match= 'População')[0]

# %%
pop_wiki2
# Out:
#     Posição  ...        País comparável (habitantes)
# 0         1  ...                Espanha (46 439 864)
# 1         2  ...              Sri Lanka (20 675 000)
# 2         3  ...          Países Baixos (16 922 900)
# 3         4  ...                  Chade (14 037 000)
# 4         5  ...                Bolívia (11 410 651)
# 5         6  ...                Bélgica (11 250 659)
# 6         7  ...            Bielorrússia (9 485 300)
# 7         8  ...  Emirados Árabes Unidos (9 157 000)
# 8         9  ...                 Áustria (8 602 112)
# 9        10  ...                  Sérvia (7 114 393)
# 10       11  ...                Paraguai (7 003 406)
# 11       12  ...                Paraguai (7 003 406)
# 12       13  ...                  Líbano (4 168 000)
# 13       14  ...                  Líbano (4 168 000)
# 14       15  ...                  Líbano (4 168 000)
# 15       16  ...                 Uruguai (3 415 866)
# 16       17  ...                 Uruguai (3 415 866)
# 17       18  ...                 Uruguai (3 415 866)
# 18       19  ...                  Kuwait (3 268 431)
# 19       20  ...                Lituânia (2 900 787)
# 20       21  ...                 Jamaica (2 717 991)
# 21       22  ...                 Namíbia (2 280 700)
# 22       23  ...                   Gabão (1 725 000)
# 23       24  ...                 Bahrein (1 359 800)
# 24       25  ...                      Fiji (859 178)
# 25       26  ...                      Fiji (859 178)
# 26       27  ...                Luxemburgo (562 958)
#
# [27 rows x 5 columns]

# %% [markdown]
# Uma terceira maneira de obter a mesma tabela seria com o auxilio da biblioteca Beaultiful Soup. Para isso, precisamos importar novas bibliotecas:

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# O comando nos retorna uma cópia do endereço html passado:

# %%
page = requests.get('https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o').content

# %% [markdown]
# Podemos agora criar nosso web scarper. É preciso passar o tipo de parse que ele utilizará. Temos opções como: html.parser, lxml e html5lib. Usaremos o primeiro.

# %%
soup = BeautifulSoup(page, 'html.parser')

# %% [markdown]
# O próximo comando nos retorna o primeiro elemento 'table' encontrado na page:

# %%
tabela_html = soup.find_all('table')[0]
tabela_html

# %% [markdown]
# Agora o pandas pode ler esse elemento e criar um dataframe a partir dele:

# %%
tabelas = pd.read_html(str(tabela_html))

# %%
tabelas
# Out:
# [    Posição  ...        País comparável (habitantes)
#  0         1  ...                Espanha (46 439 864)
#  1         2  ...              Sri Lanka (20 675 000)
#  2         3  ...          Países Baixos (16 922 900)
#  3         4  ...                  Chade (14 037 000)
#  4         5  ...                Bolívia (11 410 651)
#  5         6  ...                Bélgica (11 250 659)
#  6         7  ...            Bielorrússia (9 485 300)
#  7         8  ...  Emirados Árabes Unidos (9 157 000)
#  8         9  ...                 Áustria (8 602 112)
#  9        10  ...                  Sérvia (7 114 393)
#  10       11  ...                Paraguai (7 003 406)
#  11       12  ...                Paraguai (7 003 406)
#  12       13  ...                  Líbano (4 168 000)
#  13       14  ...                  Líbano (4 168 000)
#  14       15  ...                  Líbano (4 168 000)
#  15       16  ...                 Uruguai (3 415 866)
#  16       17  ...                 Uruguai (3 415 866)
#  17       18  ...                 Uruguai (3 415 866)
#  18       19  ...                  Kuwait (3 268 431)
#  19       20  ...                Lituânia (2 900 787)
#  20       21  ...                 Jamaica (2 717 991)
#  21       22  ...                 Namíbia (2 280 700)
#  22       23  ...                   Gabão (1 725 000)
#  23       24  ...                 Bahrein (1 359 800)
#  24       25  ...                      Fiji (859 178)
#  25       26  ...                      Fiji (859 178)
#  26       27  ...                Luxemburgo (562 958)
#
#  [27 rows x 5 columns]]

# %%
pop_wiki3 = tabelas[0]

# %%
pop_wiki3
# Out:
#     Posição  ...        País comparável (habitantes)
# 0         1  ...                Espanha (46 439 864)
# 1         2  ...              Sri Lanka (20 675 000)
# 2         3  ...          Países Baixos (16 922 900)
# 3         4  ...                  Chade (14 037 000)
# 4         5  ...                Bolívia (11 410 651)
# 5         6  ...                Bélgica (11 250 659)
# 6         7  ...            Bielorrússia (9 485 300)
# 7         8  ...  Emirados Árabes Unidos (9 157 000)
# 8         9  ...                 Áustria (8 602 112)
# 9        10  ...                  Sérvia (7 114 393)
# 10       11  ...                Paraguai (7 003 406)
# 11       12  ...                Paraguai (7 003 406)
# 12       13  ...                  Líbano (4 168 000)
# 13       14  ...                  Líbano (4 168 000)
# 14       15  ...                  Líbano (4 168 000)
# 15       16  ...                 Uruguai (3 415 866)
# 16       17  ...                 Uruguai (3 415 866)
# 17       18  ...                 Uruguai (3 415 866)
# 18       19  ...                  Kuwait (3 268 431)
# 19       20  ...                Lituânia (2 900 787)
# 20       21  ...                 Jamaica (2 717 991)
# 21       22  ...                 Namíbia (2 280 700)
# 22       23  ...                   Gabão (1 725 000)
# 23       24  ...                 Bahrein (1 359 800)
# 24       25  ...                      Fiji (859 178)
# 25       26  ...                      Fiji (859 178)
# 26       27  ...                Luxemburgo (562 958)
#
# [27 rows x 5 columns]

# %% [markdown]
# Vamos utilizar e trabalhar na tabela pop_wiki que já criamos e fizemos um tratamento inicial. Observe o seguinte:

# %%
pop_wiki.index
# Out:
# Index([' São Paulo', ' MG Minas Gerais', ' Rio de Janeiro', 'Bahia Bahia',
#        ' Paraná', ' Rio Grande do Sul', ' Pernambuco', ' Ceará', 'Pará Pará',
#        ' Santa Catarina', ' Maranhão', ' Goiás', ' Amazonas',
#        ' Espírito Santo', ' Paraíba', ' Rio Grande do Norte', ' Mato Grosso',
#        ' Alagoas', ' Piauí', ' Distrito Federal', ' Mato Grosso do Sul',
#        ' Sergipe', ' Rondônia', ' Tocantins', ' Acre', ' Amapá', ' Roraima'],
#       dtype='object', name='uf')

# %% [markdown]
# Os índices estão com vários espaços. Queremos eliminar esses espaços em branco. Para isso podemos fazer:

# %%
pop_wiki.index = pop_wiki.index.str.strip()

# %%
pop_wiki.index
# Out:
# Index(['São Paulo', 'MG Minas Gerais', 'Rio de Janeiro', 'Bahia Bahia',
#        'Paraná', 'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará Pará',
#        'Santa Catarina', 'Maranhão', 'Goiás', 'Amazonas', 'Espírito Santo',
#        'Paraíba', 'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
dados_mais_recentes = pd.DataFrame(dados_usaveis.iloc[:,-1])

# %%
dados_mais_recentes
# Out:
#                                  Total
# Unidade da Federação
# Rondônia                996,411,254.68
# Acre                    450,048,530.47
# Amazonas              1,917,247,936.05
# Roraima                 328,876,965.09
# Pará                  4,705,309,002.29
# Amapá                   309,860,092.59
# Tocantins             1,020,028,272.64
# Maranhão              3,871,069,498.04
# Piauí                 2,280,888,802.74
# Ceará                 6,591,836,650.18
# Rio Grande do Norte   2,660,122,027.15
# Paraíba               2,614,919,044.63
# Pernambuco            8,581,189,975.91
# Alagoas               2,236,415,402.51
# Sergipe               1,215,853,015.00
# Bahia                 9,791,541,570.52
# Minas Gerais         20,418,737,536.66
# Espírito Santo        3,405,850,698.58
# Rio de Janeiro       10,337,389,922.09
# São Paulo            41,396,408,548.81
# Paraná               14,681,514,706.67
# Santa Catarina        7,835,011,163.40
# Rio Grande do Sul    12,764,391,179.92
# Mato Grosso do Sul    2,324,525,096.33
# Mato Grosso           2,180,119,781.15
# Goiás                 4,973,572,261.43
# Distrito Federal      2,592,422,853.56

# %% [markdown]
# Queremos juntar os dois dataframes utilizando o join. Mas para isso funcionar, os índices devem estar todos corretos.
# Observe que os índices de pop_wiki contém pequenos erros (como 'Bahia Bahia') proveninetes da importação.
# O código abaixo corrige isso: ele percorre a lista de índices de pop_wiki e compara cada valor com a lista de estados (retirada dos índices de dados_mais_recentes. Caso o nome do estado figure na string, ele substutui a string pelo nome do estado. Assim elimamos os erros do tipo 'Bahia Bahia' (que veio da importação), mas também erros do tipo 'MG Minas Gerais' (que eu de propósito inseri manualmente, para testar o código).

# %%
lista_indices = []
for i in range(0,pop_wiki.index.shape[0]):
  for estado in dados_mais_recentes.index:
    indice = pop_wiki.index[i]
    if indice.find(estado) != -1:
      if (estado in lista_indices) == False:
        lista_indices.append(estado)

pop_wiki.index = lista_indices

# %%
pop_wiki
# Out:
#                      populacao  % pop total
# São Paulo             46289333        21.90
# Minas Gerais          21292666        10.10
# Rio de Janeiro        17366189         8.20
# Bahia                 14930634         7.10
# Paraná                11516840         5.40
# Rio Grande do Sul     11422973         5.40
# Pernambuco             9616621         4.50
# Ceará                  9187103         4.30
# Pará                   8690745         4.10
# Santa Catarina         7252502         3.40
# Maranhão               7114598         3.40
# Goiás                  7113540         3.40
# Amazonas               4207714         2.00
# Espírito Santo         4064052         1.90
# Paraíba                4039277         1.90
# Rio Grande do Norte    3534165         1.70
# Mato Grosso            3526220         1.70
# Alagoas                3351543         1.60
# Piauí                  3281480         1.60
# Distrito Federal       3055149         1.40
# Mato Grosso do Sul     2809394         1.30
# Sergipe                2318822         1.10
# Rondônia               1796460         0.80
# Tocantins              1590248         0.70
# Acre                    894470         0.40
# Amapá                   861773         0.40
# Roraima                 631181         0.30

# %% [markdown]
# Agora estamos prontos para juntar os dois dataframes

# %%
pop_wiki.join(dados_mais_recentes)
# Out:
#                      populacao  % pop total       2021/Mar
# São Paulo             46289333        21.90 177,408,317.71
# Minas Gerais          21292666        10.10  79,780,838.00
# Rio de Janeiro        17366189         8.20  49,149,884.48
# Bahia                 14930634         7.10  31,314,602.44
# Paraná                11516840         5.40  43,480,729.07
# Rio Grande do Sul     11422973         5.40  37,798,832.80
# Pernambuco             9616621         4.50  39,472,738.81
# Ceará                  9187103         4.30  17,173,151.55
# Pará                   8690745         4.10  13,069,564.31
# Santa Catarina         7252502         3.40  19,375,822.56
# Maranhão               7114598         3.40  17,294,509.11
# Goiás                  7113540         3.40  24,867,001.02
# Amazonas               4207714         2.00   6,799,060.80
# Espírito Santo         4064052         1.90  15,606,368.11
# Paraíba                4039277         1.90  12,517,894.05
# Rio Grande do Norte    3534165         1.70   8,733,455.36
# Mato Grosso            3526220         1.70   8,835,890.09
# Alagoas                3351543         1.60   8,180,887.21
# Piauí                  3281480         1.60   9,542,151.53
# Distrito Federal       3055149         1.40  14,731,938.43
# Mato Grosso do Sul     2809394         1.30   4,035,989.77
# Sergipe                2318822         1.10   3,081,081.42
# Rondônia               1796460         0.80   4,732,441.04
# Tocantins              1590248         0.70     928,756.84
# Acre                    894470         0.40   1,137,341.65
# Amapá                   861773         0.40     989,155.40
# Roraima                 631181         0.30   2,381,844.31

# %% [markdown]
# Vamos automatizar esse procedimento inteiro, criando uma função.

# %%
def tratar_tabelas(tab1_original,tab2_original):
  tab1 = tab1_original.copy()
  tab2 = tab2_original.copy()
  tab1.columns = ['posicao', 'uf', 'populacao', '% pop total', 'pais comparavel']
  tab1.drop(['posicao', 'pais comparavel'], axis = 1, inplace=
              True)
  tab1 = tab1.set_index('uf')
  tab1.replace(' ','', inplace=True, regex=True)
  tab1.replace('%','', inplace=True, regex=True)
  tab1.replace(',','.', inplace=True, regex=True)

  tab1['populacao'] = tab1['populacao'].astype(int)
  tab1['% pop total'] = tab1['% pop total'].astype(float)

  tab1.index = tab1.index.str.strip()


  lista_indices = []
  for i in range(0,tab1.shape[0]):
    for estado in tab2.index:
      indice = tab1.index[i]
      if indice.find(estado) != -1:
        if (estado in lista_indices) == False:
          lista_indices.append(estado)

  tab1.index = lista_indices
  tab3 = tab1.join(tab2)

  return tab3

# %% [markdown]
# Vamos ver se funcionou. Vamos importar novamente a tabela da Wikipedia, com outro nome:

# %%
from io import StringIO
pop_io = StringIO(dados_populacao)

wiki_teste = pd.read_csv(pop_io, sep = '\t')
wiki_teste
# Out:
#     Posição  ...                      País comparável
# 0         1  ...                 Espanha (46 439 864)
# 1         2  ...               Sri Lanka (20 675 000)
# 2         3  ...           Países Baixos (16 922 900)
# 3         4  ...                   Chade (14 037 000)
# 4         5  ...                 Bolívia (11 410 651)
# 5         6  ...                 Bélgica (11 250 659)
# 6         7  ...             Bielorrússia (9 485 300)
# 7         8  ...   Emirados Árabes Unidos (9 157 000)
# 8         9  ...                  Áustria (8 602 112)
# 9        10  ...                   Sérvia (7 114 393)
# 10       11  ...                 Paraguai (7 003 406)
# 11       12  ...                 Paraguai (7 003 406)
# 12       13  ...                   Líbano (4 168 000)
# 13       14  ...                   Líbano (4 168 000)
# 14       15  ...                   Líbano (4 168 000)
# 15       16  ...                  Uruguai (3 415 866)
# 16       17  ...                  Uruguai (3 415 866)
# 17       18  ...                  Uruguai (3 415 866)
# 18       19  ...                   Kuwait (3 268 431)
# 19       20  ...                 Lituânia (2 900 787)
# 20       21  ...                  Jamaica (2 717 991)
# 21       22  ...                  Namíbia (2 280 700)
# 22       23  ...                    Gabão (1 725 000)
# 23       24  ...                  Bahrein (1 359 800)
# 24       25  ...                       Fiji (859 178)
# 25       26  ...                       Fiji (859 178)
# 26       27  ...                 Luxemburgo (562 958)
#
# [27 rows x 5 columns]

# %%
tratar_tabelas(wiki_teste,dados_mais_recentes)
# Out:
#                      populacao  % pop total             Total
# São Paulo             46289333        21.90 41,396,408,548.81
# Minas Gerais          21292666        10.10 20,418,737,536.66
# Rio de Janeiro        17366189         8.20 10,337,389,922.09
# Bahia                 14930634         7.10  9,791,541,570.52
# Paraná                11516840         5.40 14,681,514,706.67
# Rio Grande do Sul     11422973         5.40 12,764,391,179.92
# Pernambuco             9616621         4.50  8,581,189,975.91
# Ceará                  9187103         4.30  6,591,836,650.18
# Pará                   8690745         4.10  4,705,309,002.29
# Santa Catarina         7252502         3.40  7,835,011,163.40
# Maranhão               7114598         3.40  3,871,069,498.04
# Goiás                  7113540         3.40  4,973,572,261.43
# Amazonas               4207714         2.00  1,917,247,936.05
# Espírito Santo         4064052         1.90  3,405,850,698.58
# Paraíba                4039277         1.90  2,614,919,044.63
# Rio Grande do Norte    3534165         1.70  2,660,122,027.15
# Mato Grosso            3526220         1.70  2,180,119,781.15
# Alagoas                3351543         1.60  2,236,415,402.51
# Piauí                  3281480         1.60  2,280,888,802.74
# Distrito Federal       3055149         1.40  2,592,422,853.56
# Mato Grosso do Sul     2809394         1.30  2,324,525,096.33
# Sergipe                2318822         1.10  1,215,853,015.00
# Rondônia               1796460         0.80    996,411,254.68
# Tocantins              1590248         0.70  1,020,028,272.64
# Acre                    894470         0.40    450,048,530.47
# Amapá                   861773         0.40    309,860,092.59
# Roraima                 631181         0.30    328,876,965.09
